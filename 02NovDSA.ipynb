# %%
# %cd /content/drive/MyDrive/ColabWork/ToLearnFrom/DataStructures&Algos
# Out:
# /content/drive/.shortcut-targets-by-id/1KvD768oSRUMycPS1u8l90UWy8RnfQIU8/ColabWork/ToLearnFrom/DataStructures&Algos

# %%
# !pip install jovian --upgrade --quiet
# Out:
#      |████████████████████████████████| 68 kB 3.1 MB/s
# ...

# %%
from jovian.pythondsa import evaluate_test_case

# %%
evaluate_test_case??

# %%
def evaluate_test_case(function, test_case, display=True):
    """Check if `function` works as expected for `test_case`"""
    inputs = test_case['input']

    if display:
        _show_test_case(test_case)

    start = timer()
    actual_output = function(**inputs)
    end = timer()

    runtime = math.ceil((end - start)*1e6)/1000
    if 'outputs' in test_case:
        passed = actual_output in test_case.get('outputs')
    else:
        passed = actual_output == test_case.get('output')

    result = actual_output, passed, runtime

    if display:
        _show_result(result)

    return result

# %% [markdown]
# # Simple kind of Brute force approach

# %%
def find_card(cards,query):

  pos=0
  while True:

    if cards[pos]==query:
      return pos
    pos+=1

    if pos==len(cards):
      return -1

# %%
find_card([9,7,5,3,1,0],2)
# Out:
# -1

# %%
find_card([],0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-f4f6e4016dca> in <module>()
# ----> 1 find_card([],0)
#
# <ipython-input-6-4ee13fb974e6> in find_card(cards, query)
#       4   while True:
#       5
# ----> 6     if cards[pos]==query:
#       7       return pos
#       8     pos+=1
#
# IndexError: list index out of range

# %%
def find_card(cards,query):

  pos=0
  while pos<len(cards):

    if cards[pos]==query:
      return pos
    pos+=1
  return -1

# %%
find_card([],0)
# Out:
# -1

# %%
find_card([65,40,30,6,5,6,5],6)
# Out:
# 3

# %% [markdown]
# # Now using Binary Search

# %%
def locate_card(cards, query):
    lo, hi = 0, len(cards) - 1
    
    while lo <= hi:
        mid = (lo + hi) // 2
        mid_number = cards[mid]
        
        print("lo:", lo, ", hi:", hi, ", mid:", mid, ", mid_number:", mid_number)
        
        if mid_number == query:
            return mid
        elif mid_number < query:
            hi = mid - 1  
        elif mid_number > query:
            lo = mid + 1
    
    return -1

# %%
def find_card_optimized(cards,query):

  low,hi=0,len(cards)-1

  while low <= hi:
    mid=(low+hi) // 2
    mid_card=cards[mid]

    print("lo:", low, ", hi:", hi, ", mid:", mid, ", mid_number:", mid_card)


    if mid_card==query:
      return mid
    elif mid_card < query:
      hi=mid - 1
    elif mid > query:
      low=mid - 1
  return -1

# %%
find_card_optimized([9,7,5,3,1],9)
# Out:
# lo: 0 , hi: 4 , mid: 2 , mid_number: 5
# lo: 0 , hi: 1 , mid: 0 , mid_number: 9
# 0

# %%
locate_card([9,7,5,3,1],9)
# Out:
# lo: 0 , hi: 4 , mid: 2 , mid_number: 5
# lo: 0 , hi: 1 , mid: 0 , mid_number: 9
# 0

# %% [markdown]
# # What if we have multiple instances of query no, and we want to return the index of first instance

# %%
find_card_optimized([9,9,9,7,5,3,1],9)
# Out:
# lo: 0 , hi: 6 , mid: 3 , mid_number: 7
# lo: 0 , hi: 2 , mid: 1 , mid_number: 9
# 1

# %%
import time

# %%
def find_card(cards,query):

  lo,hi=0,len(cards)-1

  while lo <= hi:

    time.sleep(1)

    mid=(lo+hi)//2
    print('Mid-Index::',mid)
    mid_card=cards[mid]
    print('Mid-Card::',mid_card)
    if mid_card==query:
      print('Mid-Card::',mid_card)

      if mid-1 >=0 and cards[mid-1]==query:

        hi=mid-1
      else:
        return mid
    elif mid_card < query:
      hi=mid-1
      print('HI::',hi)
    #elif mid_card > query:
    else: 
      lo=mid + 1
      print("LO::",lo)
  return -1

# %%
def test_location(cards, query, mid):
    mid_number = cards[mid]
    print("mid:", mid, ", mid_number:", mid_number)
    if mid_number == query:
        if mid-1 >= 0 and cards[mid-1] == query:
            return 'left'
        else:
            return 'found'
    elif mid_number < query:
        return 'left'
    else:
        return 'right'

def locate_card(cards, query):
    lo, hi = 0, len(cards) - 1
    
    while lo <= hi:
        print("lo:", lo, ", hi:", hi)
        mid = (lo + hi) // 2
        result = test_location(cards, query, mid)
        
        if result == 'found':
            return mid
        elif result == 'left':
            hi = mid - 1
        elif result == 'right':
            lo = mid + 1
    return -1

# %%
find_card([9,9,3,1],9)
# Out:
# Mid-Index:: 1
# Mid-Card:: 9
# Mid-Card:: 9
# Mid-Index:: 0
# Mid-Card:: 9
# Mid-Card:: 9
# 0

# %%
locate_card([9,9,3,1],1)
# Out:
# lo: 0 , hi: 3
# mid: 1 , mid_number: 9
# lo: 2 , hi: 3
# mid: 2 , mid_number: 3
# lo: 3 , hi: 3
# mid: 3 , mid_number: 1
# 3
