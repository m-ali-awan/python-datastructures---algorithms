# %%
import logging

# %%
logging.info('aaa')

# %%
def bubble_sort(nums):

  nums=list(nums)

  for _ in range(0,len(nums)-1):

    for i in range(0,len(nums)-1):

      if nums[i]> nums[i+1]:
        nums[i],nums[i+1]=nums[i+1],nums[i]


  return nums

# %%
test = {
    'input': {
        'nums': [42, 42, 42, 42, 42, 42, 42]
    },
    'output': [42, 42, 42, 42, 42, 42, 42]
}

# %%
# A list containing repeating elements
test4 = {
    'input': {
        'nums': [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
    },
    'output': [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
}

# %%
nums0, output0 = test['input']['nums'], test['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = bubble_sort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)
# Out:
# Input: [42, 42, 42, 42, 42, 42, 42]
# Expected output: [42, 42, 42, 42, 42, 42, 42]
# Actual output: [42, 42, 42, 42, 42, 42, 42]
# Match: True

# %%
nums0, output0 = test4['input']['nums'], test4['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = bubble_sort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)
# Out:
# Input: [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# Expected output: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
# Actual output: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
# Match: True

# %% [markdown]
# ## Insertion Sort

# %%
def insertion_sort(nums):
    nums = list(nums)
    for i in range(len(nums)):
        cur = nums.pop(i)
        print('CUR:::',cur)
        j = i-1
        while j >=0 and nums[j] > cur:
            j -= 1
            print('J::',j)
        nums.insert(j+1, cur)
        print('NUMS::',nums)
    return nums

# %%
nums.insert??
# Out:
# Object `nums.insert` not found.

# %%
nums0, output0 = test4['input']['nums'], test4['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = insertion_sort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)
# Out:
# Input: [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# Expected output: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
# CUR::: 5
# NUMS:: [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# CUR::: -12
# J:: -1
# NUMS:: [-12, 5, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# CUR::: 2
# J:: 0
# NUMS:: [-12, 2, 5, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# CUR::: 6
# NUMS:: [-12, 2, 5, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# CUR::: 1
# J:: 2
# J:: 1
# J:: 0
# NUMS:: [-12, 1, 2, 5, 6, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# CUR::: 23
# NUMS:: [-12, 1, 2, 5, 6, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# CUR::: 7
# J:: 4
# NUMS:: [-12, 1, 2, 5, 6, 7, 23, 7, -12, 6, 12, 1, -243, 1, 0]
# CUR::: 7
# J:: 5
# NUMS:: [-12, 1, 2, 5, 6, 7, 7, 23, -12, 6, 12, 1, -243, 1, 0]
# CUR::: -12
# J:: 6
# J:: 5
# J:: 4
# J:: 3
# J:: 2
# J:: 1
# J:: 0
# NUMS:: [-12, -12, 1, 2, 5, 6, 7, 7, 23, 6, 12, 1, -243, 1, 0]
# CUR::: 6
# J:: 7
# J:: 6
# J:: 5
# ...

# %% [markdown]
# ## Divide and Conquer Strategy

# %%
def merge_sort(nums):
    # Terminating condition (list of 0 or 1 elements)
    if len(nums) <= 1:
        return nums
    
    # Get the midpoint
    mid = len(nums) // 2
    
    # Split the list into two halves
    left = nums[:mid]
    right = nums[mid:]
    
    # Solve the problem for each half recursively
    left_sorted, right_sorted = merge_sort(left), merge_sort(right)
    
    # Combine the results of the two halves
    sorted_nums =  merge(left_sorted, right_sorted)
    
    return sorted_nums

# %%
def merge(nums1,nums2):

  merged=[]
  i,j=0,0

  while i < len(nums1) and j < len(nums2):

    if nums1[i]<=nums2[j]:
      merged.append(nums1[i])
      i += 1

    else:
      merged.append(nums2[j])
      j+=1

  nums1_tail=nums1[i:]
  nums2_tail=nums2[j:]

  return merged + nums1_tail + nums2_tail

# %%
merge([1, 4, 7, 9, 11], [-1, 0, 2, 3, 8, 12])
# Out:
# [-1, 0, 1, 2, 3, 4, 7, 8, 9, 11, 12]

# %%
nums0, output0 = test4['input']['nums'], test4['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = merge_sort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)
# Out:
# Input: [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# Expected output: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
# Actual output: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
# Match: True

# %% [markdown]
# ## QuickSort

# %%
def quick_sort(arr,left, right):

  if left < right:
    partition_pos=partition(arr,left,right)
    quick_sort(arr,left,partition_pos-1)
    quick_sort(arr,partition_pos+1,right)

# %%
def partition(arr,left,right):


  print("ARRAY::", arr)
  pivot=arr[right]

  print('PIVOT::',pivot)
  i=left
  j=right-1

  while i < j:
    while i < right and arr[i] < pivot:
      i+=1
    while j > left and arr[j] >= pivot:
      j-=1

    if i < j:
      arr[i], arr[j]=arr[j], arr[i]

  if arr[i] > pivot:
    arr[i],arr[right]=arr[right],arr[i]

  return i

# %%
test4
# Out:
# {'input': {'nums': [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]},
#  'output': [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]}

# %%
quick_sort(test4['input']['nums'],0,len(test4['input']['nums'])-1)
# Out:
# ARRAY:: [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
# PIVOT:: 0
# ARRAY:: [-243, -12, -12, 0, 1, 23, 7, 7, 2, 6, 12, 1, 5, 1, 6]
# PIVOT:: -12
# ARRAY:: [-243, -12, -12, 0, 1, 23, 7, 7, 2, 6, 12, 1, 5, 1, 6]
# PIVOT:: 6
# ARRAY:: [-243, -12, -12, 0, 1, 1, 5, 1, 2, 6, 12, 7, 7, 23, 6]
# PIVOT:: 2
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 1
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 1
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 6
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 23, 12]
# PIVOT:: 12
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
# PIVOT:: 7

# %%
test4
# Out:
# {'input': {'nums': [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]},
#  'output': [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]}

# %%
a=[3,7,2,5,1,88,45]

# %%
quick_sort(a,0,len(a)-1)
# Out:
# ARRAY:: [3, 7, 2, 5, 1, 88, 45]
# PIVOT:: 45
# ARRAY:: [3, 7, 2, 5, 1, 45, 88]
# PIVOT:: 1
# ARRAY:: [1, 7, 2, 5, 3, 45, 88]
# PIVOT:: 3
# ARRAY:: [1, 2, 3, 5, 7, 45, 88]
# PIVOT:: 7

# %%
a
# Out:
# [1, 2, 3, 5, 7, 45, 88]

# %%
b=[-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
quick_sort(b,0,len(b)-1)
b
# Out:
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 6
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 5
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 2
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 1
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 0
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: -12
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 1
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 12, 7, 7, 23, 6]
# PIVOT:: 6
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 23, 12]
# PIVOT:: 12
# ARRAY:: [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
# PIVOT:: 7
# [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
